# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Area": [1400, 1600, 1700, 1875, 1100, 1550, 1800, 2400],
    "Bedrooms": [3, 3, 3, 4, 2, 3, 4, 4],
    "Bathrooms": [2, 2, 2, 3, 1, 2, 3, 3],
    "Price": [245000, 312000, 279000, 308000, 199000, 310000, 360000, 410000]
}

df = pd.DataFrame(data)
df
# Out:
#    Area  Bedrooms  Bathrooms   Price
# 0  1400         3          2  245000
# 1  1600         3          2  312000
# 2  1700         3          2  279000
# 3  1875         4          3  308000
# 4  1100         2          1  199000
# 5  1550         3          2  310000
# 6  1800         4          3  360000
# 7  2400         4          3  410000

# %%
df.corr()
# Out:
#                Area  Bedrooms  Bathrooms     Price
# Area       1.000000  0.861264   0.861264  0.921518
# Bedrooms   0.861264  1.000000   1.000000  0.848819
# Bathrooms  0.861264  1.000000   1.000000  0.848819
# Price      0.921518  0.848819   0.848819  1.000000

# %%
# Heatmap
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Pairplot
sns.pairplot(df)
plt.show()
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
